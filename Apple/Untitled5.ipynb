# %%
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.model_selection import learning_curve

# モデルの初期化
xgb = XGBRegressor(random_state=42)

# 学習曲線の計算
train_sizes, train_scores, val_scores = learning_curve(
    xgb, X, y, cv=5, scoring='neg_mean_absolute_error',
    train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=-1
)

# スコアの平均と標準偏差の計算
train_scores_mean = -np.mean(train_scores, axis=1)
val_scores_mean = -np.mean(val_scores, axis=1)

# 学習曲線のプロット
plt.figure()
plt.plot(train_sizes, train_scores_mean, label='Training MAE')
plt.plot(train_sizes, val_scores_mean, label='Validation MAE')
plt.xlabel('Training size')
plt.ylabel('MAE')
plt.title('Learning Curve')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 xgb = XGBRegressor(random_state=42)
#       8 # 学習曲線の計算
#       9 train_sizes, train_scores, val_scores = learning_curve(
# ---> 10     xgb, X, y, cv=5, scoring='neg_mean_absolute_error',
#      11     train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=-1
#      12 )
#      14 # スコアの平均と標準偏差の計算
#      15 train_scores_mean = -np.mean(train_scores, axis=1)
#
# NameError: name 'X' is not defined
