# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.utils import resample
from collections import defaultdict

# %%
# TCVファイルの読み込み
train_data = pd.read_csv('../000.data/train/train_C.tsv', sep="\t")
test = pd.read_csv('../000.data/test.tsv', sep="\t")

# %%
# 末尾が "_C" のテストデータだけを抽出
test_data = test[test["user_id"].str.endswith("_C")]

# %%
# 関連度スコアの設定
def compute_relevance(row):
    if row["event_type"] == 3 and row["ad"] == 1:  # 広告経由の購入
        return 3
    elif row["event_type"] == 2:  # 広告クリック
        return 2
    elif row["event_type"] == 1:  # 詳細ページ閲覧
        return 1
    else:  # カート追加
        return 0

train_data["relevance"] = train_data.apply(compute_relevance, axis=1)

# %%
# タイムスタンプをdatetime型に変換
train_data["time_stamp"] = pd.to_datetime(train_data["time_stamp"])

# %%
# 最新の行動からの経過時間（秒）
train_data["time_since_last"] = (train_data["time_stamp"].max() - train_data["time_stamp"]).dt.total_seconds()

# %%
# ユーザーごとの行動回数集計
user_features = train_data.groupby("user_id").agg(
    user_total_interactions=("product_id", "count"),
    user_unique_products=("product_id", "nunique"),
    user_avg_time_since=("time_since_last", "mean")
).reset_index()

# %%
# 商品ごとの人気度
product_features = train_data.groupby("product_id").agg(
    product_total_interactions=("user_id", "count"),
    product_unique_users=("user_id", "nunique")
).reset_index()

# %%
# データ結合
train_data = train_data.merge(user_features, on="user_id", how="left")
train_data = train_data.merge(product_features, on="product_id", how="left")

# %%
# 学習用特徴量
features = [
    "user_total_interactions", "user_unique_products", "user_avg_time_since",
    "product_total_interactions", "product_unique_users"
]

# %%
# クラス不均衡に対する学習データのバランス調整
train_data_pos = train_data[train_data["relevance"] >= 2]  # 広告クリックと購入のデータ
train_data_neg = train_data[train_data["relevance"] < 2]   # その他のデータ

# %%
# 多数派クラス（詳細閲覧・カート）をアンダーサンプリング
train_data_neg_undersampled = resample(train_data_neg, 
                                      replace=True, 
                                      n_samples=500000,
                                      random_state=42)

# %%
# 少数派クラス（購入・広告クリック）をオーバーサンプリング
train_data_pos_oversampled = resample(train_data_pos, 
                                      replace=True, 
                                      n_samples=1000000,
                                      random_state=42)

# %%
# サンプリング後のデータ
train_data_balanced = pd.concat([train_data_neg_undersampled, train_data_pos_oversampled])

# %%
# クロスバリデーション設定
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# 評価指標を格納するリスト
ndcg_scores = []

# %%
for train_index, val_index in kf.split(train_data_balanced):
    train_set = train_data_balanced.iloc[train_index]
    val_set = train_data_balanced.iloc[val_index]
    
    # 特徴量とラベル
    X_train = train_set[features]
    y_train = train_set["relevance"]
    X_val = val_set[features]
    y_val = val_set["relevance"]
    
    # クエリごとのデータ数（ユーザーごと）
    group_train = train_set.groupby("user_id").size().to_numpy()
    group_val = val_set.groupby("user_id").size().to_numpy()
    
    # XGBoost DMatrix に変換
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtrain.set_group(group_train)

    dval = xgb.DMatrix(X_val, label=y_val)
    dval.set_group(group_val)

    # 学習パラメータ設定（過学習防止のための調整）
    params = {
        "objective": "rank:ndcg",
        "eval_metric": "ndcg",
        "booster": "gbtree",
        "eta": 0.1,
        "max_depth": 6,
        "min_child_weight": 10,
        "subsample": 0.8,               # サブサンプリング（学習データの80%を使用）
        "colsample_bytree": 0.8,        # 特徴量のサブサンプリング
        "lambda": 1.0,                  # L2正則化
        "gamma": 0.1,                   # 木の分岐時の正則化
    }
    
    # モデル学習
    evals_result = {}  # 追加: early stoppingのログを格納
    model = xgb.train(
        params, dtrain, num_boost_round=200,
        evals=[(dtrain, "train"), (dval, "val")],  # 検証データを明示
        evals_result=evals_result,  # 追加: early stoppingのための評価ログ
        early_stopping_rounds=20,  # early stopping を適用
        verbose_eval=10
    )
    
    # バリデーションデータの nDCG 計算
    ground_truth_val = defaultdict(dict)
    for _, row in val_set.iterrows():
        ground_truth_val[row["user_id"]][row["product_id"]] = row["relevance"]

    # バリデーションデータのコピーを作成
    val_set_copy = val_set.copy()

    # バリデーションデータに対してスコアを設定
    val_set_copy["score"] = model.predict(xgb.DMatrix(val_set_copy[features]))

    # nDCG の計算
    def dcg_at_k(relevance_scores, k):
        relevance_scores = np.asarray(relevance_scores)[:k]
        return np.sum(relevance_scores / np.log2(np.arange(2, relevance_scores.size + 2)))

    def ndcg_at_k(relevance_scores, k):
        dcg = dcg_at_k(relevance_scores, k)
        ideal_dcg = dcg_at_k(sorted(relevance_scores, reverse=True), k)
        return dcg / ideal_dcg if ideal_dcg > 0 else 0

    def evaluate_ndcg(data, ground_truth, k=22):
        ndcg_scores = []
        for user_id, group in data.groupby("user_id"):
            predicted_items = group.sort_values("score", ascending=False)["product_id"].tolist()
            relevance_scores = [ground_truth[user_id].get(item, 0) for item in predicted_items]
            ndcg_scores.append(ndcg_at_k(relevance_scores, k))
        return np.mean(ndcg_scores) if ndcg_scores else 0
    
    ndcg_val = evaluate_ndcg(val_set_copy, ground_truth_val, k=22)
    ndcg_scores.append(ndcg_val)
    print(f"Validation nDCG@22: {ndcg_val:.4f}")
# Out:
# [0]	train-ndcg:0.97492	val-ndcg:0.99056
# [10]	train-ndcg:0.98637	val-ndcg:0.99470
# [20]	train-ndcg:0.98883	val-ndcg:0.99554
# [30]	train-ndcg:0.98978	val-ndcg:0.99592
# [40]	train-ndcg:0.99046	val-ndcg:0.99619
# [50]	train-ndcg:0.99168	val-ndcg:0.99667
# [60]	train-ndcg:0.99292	val-ndcg:0.99716
# [70]	train-ndcg:0.99369	val-ndcg:0.99744
# [80]	train-ndcg:0.99438	val-ndcg:0.99772
# [90]	train-ndcg:0.99508	val-ndcg:0.99796
# [100]	train-ndcg:0.99565	val-ndcg:0.99817
# [110]	train-ndcg:0.99636	val-ndcg:0.99847
# [120]	train-ndcg:0.99681	val-ndcg:0.99862
# [130]	train-ndcg:0.99709	val-ndcg:0.99875
# [140]	train-ndcg:0.99730	val-ndcg:0.99882
# [150]	train-ndcg:0.99746	val-ndcg:0.99889
# [160]	train-ndcg:0.99763	val-ndcg:0.99895
# [170]	train-ndcg:0.99784	val-ndcg:0.99905
# [180]	train-ndcg:0.99797	val-ndcg:0.99910
# [190]	train-ndcg:0.99812	val-ndcg:0.99916
# [199]	train-ndcg:0.99829	val-ndcg:0.99922
# Validation nDCG@22: 0.9895
# [0]	train-ndcg:0.97441	val-ndcg:0.99010
# [10]	train-ndcg:0.98429	val-ndcg:0.99374
# [20]	train-ndcg:0.98558	val-ndcg:0.99428
# [30]	train-ndcg:0.98948	val-ndcg:0.99591
# [40]	train-ndcg:0.99151	val-ndcg:0.99665
# [50]	train-ndcg:0.99201	val-ndcg:0.99685
# [60]	train-ndcg:0.99271	val-ndcg:0.99709
# [70]	train-ndcg:0.99351	val-ndcg:0.99743
# [80]	train-ndcg:0.99406	val-ndcg:0.99764
# [90]	train-ndcg:0.99465	val-ndcg:0.99788
# [100]	train-ndcg:0.99547	val-ndcg:0.99823
# [110]	train-ndcg:0.99625	val-ndcg:0.99852
# [120]	train-ndcg:0.99645	val-ndcg:0.99860
# [130]	train-ndcg:0.99685	val-ndcg:0.99872
# [140]	train-ndcg:0.99717	val-ndcg:0.99886
# [150]	train-ndcg:0.99738	val-ndcg:0.99894
# [160]	train-ndcg:0.99770	val-ndcg:0.99906
# [170]	train-ndcg:0.99784	val-ndcg:0.99911
# [180]	train-ndcg:0.99808	val-ndcg:0.99921
# [190]	train-ndcg:0.99823	val-ndcg:0.99926
# [199]	train-ndcg:0.99845	val-ndcg:0.99935
# Validation nDCG@22: 0.9897
# [0]	train-ndcg:0.97477	val-ndcg:0.99030
# [10]	train-ndcg:0.98455	val-ndcg:0.99403
# [20]	train-ndcg:0.98568	val-ndcg:0.99443
# [30]	train-ndcg:0.98880	val-ndcg:0.99562
# [40]	train-ndcg:0.99040	val-ndcg:0.99628
# [50]	train-ndcg:0.99159	val-ndcg:0.99676
# [60]	train-ndcg:0.99271	val-ndcg:0.99721
# [70]	train-ndcg:0.99376	val-ndcg:0.99757
# [80]	train-ndcg:0.99436	val-ndcg:0.99780
# [90]	train-ndcg:0.99529	val-ndcg:0.99816
# [100]	train-ndcg:0.99610	val-ndcg:0.99849
# [110]	train-ndcg:0.99647	val-ndcg:0.99862
# [120]	train-ndcg:0.99680	val-ndcg:0.99875
# [130]	train-ndcg:0.99699	val-ndcg:0.99882
# [140]	train-ndcg:0.99734	val-ndcg:0.99895
# [150]	train-ndcg:0.99757	val-ndcg:0.99904
# [160]	train-ndcg:0.99776	val-ndcg:0.99910
# [170]	train-ndcg:0.99798	val-ndcg:0.99921
# [180]	train-ndcg:0.99817	val-ndcg:0.99927
# [190]	train-ndcg:0.99833	val-ndcg:0.99934
# [199]	train-ndcg:0.99847	val-ndcg:0.99938
# Validation nDCG@22: 0.9898
# [0]	train-ndcg:0.97375	val-ndcg:0.98982
# [10]	train-ndcg:0.98562	val-ndcg:0.99443
# [20]	train-ndcg:0.98785	val-ndcg:0.99518
# [30]	train-ndcg:0.98910	val-ndcg:0.99570
# [40]	train-ndcg:0.98993	val-ndcg:0.99607
# [50]	train-ndcg:0.99154	val-ndcg:0.99676
# [60]	train-ndcg:0.99293	val-ndcg:0.99725
# [70]	train-ndcg:0.99394	val-ndcg:0.99763
# [80]	train-ndcg:0.99440	val-ndcg:0.99779
# [90]	train-ndcg:0.99487	val-ndcg:0.99798
# [100]	train-ndcg:0.99533	val-ndcg:0.99817
# [110]	train-ndcg:0.99560	val-ndcg:0.99826
# [120]	train-ndcg:0.99610	val-ndcg:0.99846
# [130]	train-ndcg:0.99686	val-ndcg:0.99880
# [140]	train-ndcg:0.99724	val-ndcg:0.99894
# [150]	train-ndcg:0.99755	val-ndcg:0.99904
# [160]	train-ndcg:0.99779	val-ndcg:0.99913
# [170]	train-ndcg:0.99797	val-ndcg:0.99918
# [180]	train-ndcg:0.99818	val-ndcg:0.99926
# [190]	train-ndcg:0.99834	val-ndcg:0.99933
# [199]	train-ndcg:0.99852	val-ndcg:0.99938
# Validation nDCG@22: 0.9896
# [0]	train-ndcg:0.97586	val-ndcg:0.99038
# [10]	train-ndcg:0.98497	val-ndcg:0.99396
# [20]	train-ndcg:0.98795	val-ndcg:0.99525
# [30]	train-ndcg:0.98995	val-ndcg:0.99607
# [40]	train-ndcg:0.99071	val-ndcg:0.99641
# [50]	train-ndcg:0.99148	val-ndcg:0.99669
# [60]	train-ndcg:0.99269	val-ndcg:0.99714
# [70]	train-ndcg:0.99371	val-ndcg:0.99755
# [80]	train-ndcg:0.99475	val-ndcg:0.99795
# [90]	train-ndcg:0.99556	val-ndcg:0.99826
# [100]	train-ndcg:0.99618	val-ndcg:0.99849
# [110]	train-ndcg:0.99659	val-ndcg:0.99864
# [120]	train-ndcg:0.99684	val-ndcg:0.99873
# [130]	train-ndcg:0.99704	val-ndcg:0.99880
# [140]	train-ndcg:0.99724	val-ndcg:0.99891
# [150]	train-ndcg:0.99748	val-ndcg:0.99900
# [160]	train-ndcg:0.99763	val-ndcg:0.99907
# [170]	train-ndcg:0.99788	val-ndcg:0.99918
# [180]	train-ndcg:0.99805	val-ndcg:0.99924
# [190]	train-ndcg:0.99822	val-ndcg:0.99932
# [199]	train-ndcg:0.99834	val-ndcg:0.99936
# Validation nDCG@22: 0.9896

# %%
# クロスバリデーションの平均 nDCG を表示
print(f"Average nDCG@22 from CV: {np.mean(ndcg_scores):.4f}")
# Out:
# Average nDCG@22 from CV: 0.9897

# %%
# テストデータの処理
candidate_products = train_data.groupby("product_id")["user_id"].count().reset_index()
candidate_products = candidate_products.sort_values("user_id", ascending=False).head(22)  # 上位22商品

# %%
# すべてのユーザーに候補商品を紐づける
test_data = test_data.assign(key=1).merge(candidate_products.assign(key=1), on="key").drop("key", axis=1)
test_data = test_data.rename(columns={'user_id_x': 'user_id'}).drop(columns=['user_id_y'])

# %%
# 評価データの前処理（学習データと同じ特徴量処理を適用）
test_data = test_data.merge(user_features, on="user_id", how="left")
test_data = test_data.merge(product_features, on="product_id", how="left")
test_data.fillna(0, inplace=True)

# %%
# 予測用データ
X_test = test_data[features]
dtest = xgb.DMatrix(X_test)

# %%
# 予測スコアの計算
test_data["score"] = model.predict(dtest)

# %%
# 各ユーザーごとにランキング付け（スコアが高い順）
test_data["rank"] = test_data.groupby("user_id")["score"].rank(ascending=False, method="first")

# %%
# テストデータの nDCG 計算
ground_truth_test = defaultdict(dict)
for _, row in train_data.iterrows():
    ground_truth_test[row["user_id"]][row["product_id"]] = row["relevance"]

ndcg_test = evaluate_ndcg(test_data, ground_truth_test, k=22)
print(f"Test nDCG@22: {ndcg_test:.4f}")
# Out:
# Test nDCG@22: 0.0392

# %%
# 提出用データの作成（上位 22 件のみ）
submission = test_data[test_data["rank"] <= 22][["user_id", "product_id", "rank"]]
submission['rank'] = submission['rank'].astype(int)

# %%
# 保存
submission.to_csv('./predict_file/predictions_C.tsv', sep="\t", index=False)
