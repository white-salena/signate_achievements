# %% [markdown]
# #### data_check結果
# ・データ内容：人材<br>
# ・行動種別：全てあり<br>
# 　　1    1981780<br>
# 　　0    1286738<br>
# 　　3      74561<br>
# 　　2      33414<br>
# ・データ欠損：なし<br>
# ・重複行：17行あり

# %%
import pandas as pd

# %%
#ファイル読み込み
df = pd.read_csv('../000.data/train/train_A.tsv', sep="\t")

# %%
#重複行の削除
df_unique = df.drop_duplicates()

# %%
#各列の情報確認
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3376476 entries, 0 to 3376492
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     object
#  1   product_id  object
#  2   event_type  int64
#  3   ad          int64
#  4   time_stamp  object
# dtypes: int64(2), object(3)
# memory usage: 154.6+ MB

# %%
#行動種別(event_type)毎の数
df_unique['event_type'].value_counts()
# Out:
# event_type
# 1    1981767
# 0    1286735
# 3      74561
# 2      33413
# Name: count, dtype: int64

# %%
#コンバージョンの数
df_unique['ad'].value_counts()
# Out:
# ad
# -1    3301915
#  1      57398
#  0      17163
# Name: count, dtype: int64

# %%
#データフレームのコピー
train = df_unique.copy()

# %%
#ユーザー毎の人気度を追加
train['user_interest'] = train[train['event_type'].isin([0, 1, 3])].groupby('user_id')['event_type'].transform('count')

# %%
#商品毎の人気度を追加
train['product_interest'] = train[train['event_type'].isin([0, 1, 3])].groupby('product_id')['event_type'].transform('count')

# %%
#user_idとproduct_idを数値化
train['user_id'] = train['user_id'].astype('category').cat.codes
train['product_id'] = train['product_id'].astype('category').cat.codes

# %%
# time_stamp を datetime 型に変換
train['time_stamp'] = pd.to_datetime(train['time_stamp'])

# %%
print(train)
# Out:
#          user_id  product_id  event_type  ad              time_stamp  \
# 0              0        9081           1  -1 2017-04-08 12:09:04.629
# 1              0        9081           1  -1 2017-04-27 12:55:57.783
# 2              0       13812           1  -1 2017-04-08 11:57:53.746
# 3              0        1235           1  -1 2017-04-08 12:04:26.008
# 4              0        3260           1  -1 2017-04-08 12:05:31.326
# ...          ...         ...         ...  ..                     ...
# 3376488    23567        5276           1  -1 2017-04-28 11:07:20.023
# 3376489    23567        8124           1  -1 2017-04-28 11:00:35.549
# 3376490    23567        1564           1  -1 2017-04-28 10:58:51.575
# 3376491    23567        7544           1  -1 2017-04-28 10:59:11.325
# 3376492    23567        7544           1  -1 2017-04-28 11:11:06.644
#
#          user_interest  product_interest
# 0                 15.0             368.0
# 1                 15.0             368.0
# 2                 15.0            1153.0
# 3                 15.0             521.0
# 4                 15.0             347.0
# ...                ...               ...
# 3376488           14.0              26.0
# 3376489           14.0              16.0
# 3376490           14.0              21.0
# 3376491           14.0               8.0
# 3376492           14.0               8.0
#
# [3376476 rows x 7 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3376476 entries, 0 to 3376492
# Data columns (total 7 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           int32
#  1   product_id        int16
#  2   event_type        int64
#  3   ad                int64
#  4   time_stamp        datetime64[ns]
#  5   user_interest     float64
#  6   product_interest  float64
# dtypes: datetime64[ns](1), float64(2), int16(1), int32(1), int64(2)
# memory usage: 173.9 MB

# %%
#前処理結果をcsvへ
train.to_csv('./train/train_A.csv', index_label=False)
