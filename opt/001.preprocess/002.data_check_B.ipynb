# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#ファイル読み込み
train = pd.read_csv('../000.data/train/train_B.tsv', sep="\t")

# %%
#各列の情報確認
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113425 entries, 0 to 1113424
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   user_id     1113425 non-null  object
#  1   product_id  1113425 non-null  object
#  2   event_type  1113425 non-null  int64
#  3   ad          1113425 non-null  int64
#  4   time_stamp  1113425 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 42.5+ MB

# %%
#基本的な統計情報の確認
train.describe()
# Out:
#          event_type            ad
# count  1.113425e+06  1.113425e+06
# mean   9.948088e-01 -9.684155e-01
# std    3.582346e-01  2.340070e-01
# min    0.000000e+00 -1.000000e+00
# 25%    1.000000e+00 -1.000000e+00
# 50%    1.000000e+00 -1.000000e+00
# 75%    1.000000e+00 -1.000000e+00
# max    3.000000e+00  1.000000e+00

# %%
#カテゴリーデータ(文字列データ)の統計情報の確認
train.describe(include='object')
# Out:
#           user_id  product_id               time_stamp
# count     1113425     1113425                  1113425
# unique      23843       16894                  1113128
# top     0020791_B  00012096_b  2017-04-08 03:36:30.299
# freq        12335        1454                        2

# %%
#データ欠損行数の確認
train.isnull().sum()
# Out:
# user_id       0
# product_id    0
# event_type    0
# ad            0
# time_stamp    0
# dtype: int64

# %%
#重複行数の確認
train.duplicated().sum()
# Out:
# 10

# %%
#データ欠損値(NaN)の可視化
sns.heatmap(train.isnull(),cbar=False)
plt.show()

# %%
#行動種別(event_type)毎の数
train['event_type'].value_counts()
# Out:
# event_type
# 1    1035637
# 0      52639
# 3      21710
# 2       3439
# Name: count, dtype: int64

# %%
#コンバージョンの数
train['ad'].value_counts()
# Out:
# ad
# -1    1091715
#  1      13457
#  0       8253
# Name: count, dtype: int64
