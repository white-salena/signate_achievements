# %%
import pandas as pd

from Dataset import read_train_tsv, read_test_tsv
from Feature import UserFeature, ItemFeature, compute_relevance

# %%
# 学習データ読み込み
train_A = read_train_tsv('A')

# %%
# 予測データ読み込み+分割
test_A = read_test_tsv('A')

# %%
# 関連度スコアの設定
train_A['relevance'] = train_A.apply(compute_relevance, axis=1)

# %%
# ユーザ関連の特徴量生成クラスをインスタンス化
user_A = UserFeature(train_A, 'relevance')

# %%
# ユーザID毎に行動種別の集計(但し関連度を基準)
user_A.relevance_count()

# %%
user_A.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376493 entries, 0 to 3376492
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user_id          object
#  1   product_id       object
#  2   event_type       int64
#  3   ad               int64
#  4   time_stamp       datetime64[ns]
#  5   relevance        int64
#  6   weekday          object
#  7   date             datetime64[ns]
#  8   weight_r_0.95    float64
#  9   weight_r_0.9     float64
#  10  weight_r_0.8     float64
#  11  user_id_count_0  float64
#  12  user_id_count_1  float64
#  13  user_id_count_2  float64
#  14  user_id_count_3  float64
# dtypes: datetime64[ns](2), float64(7), int64(3), object(3)
# memory usage: 386.4+ MB

# %%
user_A.df
# Out:
#            user_id  product_id  event_type  ad              time_stamp  \
# 0        0000000_A  00009250_a           1  -1 2017-04-08 12:09:04.629
# 1        0000000_A  00009250_a           1  -1 2017-04-27 12:55:57.783
# 2        0000000_A  00014068_a           1  -1 2017-04-08 11:57:53.746
# 3        0000000_A  00001254_a           1  -1 2017-04-08 12:04:26.008
# 4        0000000_A  00003316_a           1  -1 2017-04-08 12:05:31.326
# ...            ...         ...         ...  ..                     ...
# 3376488  0023567_A  00005376_a           1  -1 2017-04-28 11:07:20.023
# 3376489  0023567_A  00008280_a           1  -1 2017-04-28 11:00:35.549
# 3376490  0023567_A  00001591_a           1  -1 2017-04-28 10:58:51.575
# 3376491  0023567_A  00007688_a           1  -1 2017-04-28 10:59:11.325
# 3376492  0023567_A  00007688_a           1  -1 2017-04-28 11:11:06.644
#
#          relevance   weekday       date  weight_r_0.95  weight_r_0.9  \
# ...
