# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#ファイル読み込み
train = pd.read_csv('../000.data/train/train_D.tsv', sep="\t")

# %%
#各列の情報確認
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3572842 entries, 0 to 3572841
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     object
#  1   product_id  object
#  2   event_type  int64
#  3   ad          int64
#  4   time_stamp  object
# dtypes: int64(2), object(3)
# memory usage: 136.3+ MB

# %%
#基本的な統計情報の確認
train.describe()
# Out:
#          event_type            ad
# count  3.572842e+06  3.572842e+06
# mean   2.944527e-01 -9.995712e-01
# std    4.572329e-01  2.913761e-02
# min    0.000000e+00 -1.000000e+00
# 25%    0.000000e+00 -1.000000e+00
# 50%    0.000000e+00 -1.000000e+00
# 75%    1.000000e+00 -1.000000e+00
# max    3.000000e+00  1.000000e+00

# %%
#カテゴリーデータ(文字列データ)の統計情報の確認
train.describe(include='object')
# Out:
#           user_id  product_id               time_stamp
# count     3572842     3572842                  3572842
# unique     108607      791822                  3244361
# top     0100726_D  00308063_d  2017-04-27 16:09:20.912
# freq        14761        1163                       13

# %%
#データ欠損行数の確認
train.isnull().sum()
# Out:
# user_id       0
# product_id    0
# event_type    0
# ad            0
# time_stamp    0
# dtype: int64

# %%
#重複行数の確認
train.duplicated().sum()
# Out:
# 4180

# %%
#データ欠損値(NaN)の可視化
sns.heatmap(train.isnull(),cbar=False)
plt.show()

# %%
#行動種別(event_type)毎の数
train['event_type'].value_counts()
# Out:
# event_type
# 0    2522371
# 1    1049690
# 3        781
# Name: count, dtype: int64

# %%
#コンバージョンの数
train['ad'].value_counts()
# Out:
# ad
# -1    3572061
#  1        751
#  0         30
# Name: count, dtype: int64
