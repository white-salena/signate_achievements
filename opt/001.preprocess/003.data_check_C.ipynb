# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#ファイル読み込み
train = pd.read_csv('../000.data/train/train_C.tsv', sep="\t")

# %%
#各列の情報確認
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1666650 entries, 0 to 1666649
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   user_id     1666650 non-null  object
#  1   product_id  1666650 non-null  object
#  2   event_type  1666650 non-null  int64
#  3   ad          1666650 non-null  int64
#  4   time_stamp  1666650 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 63.6+ MB

# %%
#基本的な統計情報の確認
train.describe()
# Out:
#          event_type            ad
# count  1.666650e+06  1.666650e+06
# mean   1.010432e+00 -9.988792e-01
# std    1.093275e-01  4.161204e-02
# min    1.000000e+00 -1.000000e+00
# 25%    1.000000e+00 -1.000000e+00
# 50%    1.000000e+00 -1.000000e+00
# 75%    1.000000e+00 -1.000000e+00
# max    3.000000e+00  1.000000e+00

# %%
#カテゴリーデータ(文字列データ)の統計情報の確認
train.describe(include='object')
# Out:
#           user_id  product_id               time_stamp
# count     1666650     1666650                  1666650
# unique      43271      313609                  1665976
# top     0034954_C  00090217_c  2017-04-26 05:59:20.035
# freq         2772        3320                        3

# %%
#データ欠損行数の確認
train.isnull().sum()
# Out:
# user_id       0
# product_id    0
# event_type    0
# ad            0
# time_stamp    0
# dtype: int64

# %%
#重複行数の確認
train.duplicated().sum()
# Out:
# 13

# %%
#データ欠損値(NaN)の可視化
sns.heatmap(train.isnull(),cbar=False)
plt.show()

# %%
#行動種別(event_type)毎の数
train['event_type'].value_counts()
# Out:
# event_type
# 1    1650622
# 2      14670
# 3       1358
# Name: count, dtype: int64

# %%
#コンバージョンの数
train['ad'].value_counts()
# Out:
# ad
# -1    1665292
#  0        848
#  1        510
# Name: count, dtype: int64
