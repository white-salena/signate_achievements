# %%
import pandas as pd

df = pd.read_csv("train_balanced_pre.csv")
#df = pd.read_csv("train_pre.csv")

# IDと賃料以外の列について要素毎の数を表示
for column in df.columns:
    if column not in ['id', '賃料']:
        print(f"{column} の要素毎の数:\n{df[column].value_counts()}\n")
# Out:
# アクセス の要素毎の数:
# アクセス
# 0.0    52008
# 0.5    35493
# 1.0     2499
# Name: count, dtype: int64
#
# 間取り の要素毎の数:
# 間取り
# 0.411765    10336
# 0.176471    10278
# 0.000000     8670
# 0.117647     7648
# 0.294118     7208
# 0.352941     7025
# 0.529412     6711
# 0.235294     6152
# 0.588235     5996
# 0.058824     4305
# 0.764706     4049
# 0.705882     3509
# 0.823529     3022
# 0.647059     2892
# 0.470588     1183
# 1.000000     1016
# Name: count, dtype: int64
#
# 築年数 の要素毎の数:
# 築年数
# 0.6    23349
# 0.4    21732
# 0.0    12544
# 0.2    11925
# 0.8    10953
# 1.0     9497
# Name: count, dtype: int64
#
# 面積 の要素毎の数:
# 面積
# 1.0    40853
# 0.8    18744
# 0.6    14054
# 0.4     8846
# 0.2     5325
# 0.0     2178
# Name: count, dtype: int64
#
# 建物構造 の要素毎の数:
# 建物構造
# 0.75    24972
# 0.50    22278
# 0.25    21769
# 0.00    18201
# 1.00     2780
# Name: count, dtype: int64
#
# 緯度 の要素毎の数:
# 緯度
# 0.857143    6154
# 0.904762    4900
# 0.916667    4717
# 0.869048    4307
# 0.892857    4201
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90000 entries, 0 to 89999
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   賃料      90000 non-null  int64
#  1   アクセス    90000 non-null  float64
#  2   間取り     90000 non-null  float64
#  3   築年数     90000 non-null  float64
#  4   面積      90000 non-null  float64
#  5   建物構造    90000 non-null  float64
#  6   緯度      90000 non-null  float64
#  7   経度      90000 non-null  float64
#  8   最上階フラグ  90000 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 6.2 MB

# %%
df2 = pd.read_csv("test_pre2.csv")

# IDと賃料以外の列について要素毎の数を表示
for column in df2.columns:
    if column not in ['id']:
        print(f"{column} の要素毎の数:\n{df2[column].value_counts()}\n")
# Out:
# アクセス の要素毎の数:
# アクセス
# 0.0    24462
# 0.5     6424
# 1.0      376
# Name: count, dtype: int64
#
# 間取り の要素毎の数:
# 間取り
# 0.000000    11786
# 0.294118     5128
# 0.058824     5095
# 0.117647     2748
# 0.235294     1902
# 0.176471     1819
# 0.352941     1181
# 0.529412      889
# 0.411765      436
# 0.588235      138
# 0.705882       55
# 0.647059       28
# 0.764706       19
# 0.941176       11
# 0.470588        8
# 0.823529        6
# 0.882353        6
# 1.000000        1
# Name: count, dtype: int64
#
# 築年数 の要素毎の数:
# 築年数
# 0.0    11973
# 0.2     7960
# 0.4     5285
# 0.6     4163
# 0.8     1503
# 1.0      378
# Name: count, dtype: int64
#
# 面積 の要素毎の数:
# 面積
# 0.4    11861
# 1.0     5471
# 0.6     4861
# 0.8     4478
# 0.2     4460
# 0.0      131
# Name: count, dtype: int64
#
# 建物構造 の要素毎の数:
# 建物構造
# 0.00    20012
# 0.25     5550
# 0.50     3769
# 0.75     1796
# 1.00      132
# Name: count, dtype: int64
#
# 緯度 の要素毎の数:
# 緯度
# 0.857143    2415
# 0.869048    2243
# 0.892857    2072
# ...
